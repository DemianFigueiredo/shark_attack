# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Shark_Path = 'attacks.csv'

Data = pd.read_csv(Shark_Path, encoding='latin-1')

pd.set_option('display.max_rows', None)

pd.set_option('display.max_columns', None)

# %%
Data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
print(Data.shape)
# Out:
# (25723, 24)

# %%
Data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
null_counts = Data.isnull().sum()
print(null_counts[null_counts > 0])
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
# CLEAN ROW WITH ALL NULL

all_null_rows_count = Data.isnull().all(axis=1).sum()
all_null_rows_count
# Out:
# 17020

# %%
# CLEAN ROW WITH ALL NULL

Data_cleaned = Data.dropna(how='all')
Data_cleaned.head( )
print(Data_cleaned.shape)
# Out:
# (8703, 24)

# %%
# CLEAN ROW WITH ALL NULL

Data = Data_cleaned
print(Data.shape)
# Out:
# (8703, 24)

# %%
# CLEAN ROW WITH TYPE Provoked, Nan, Boatomg, Questionable, Invalid, Sea Disaster

unique_values = Data['Type'].unique()
unique_values
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
# CLEAN ROW WITH TYPE Provoked, Nan, Boatomg, Questionable, Invalid,  Sea Disaster

count_prov = Data['Type'].value_counts()['Provoked']
print(count_prov)
count_inv = Data['Type'].value_counts()['Invalid']
print(count_inv)
count_omg = Data['Type'].value_counts()['Boatomg']
print(count_omg)
count_sea = Data['Type'].value_counts()['Sea Disaster']
print(count_sea)
count_quest = Data['Type'].value_counts()['Questionable']
print(count_quest)
null_count = Data['Type'].isnull().sum()
print(null_count)
# Out:
# 574
# 547
# 1
# 239
# 2
# 2405

# %%
# CLEAN ROW WITH TYPE Provoked, Nan, Boatomg, Questionable, Invalid,  Sea Disaster

filtered_rows_types = Data[(Data['Type'] == 'Unprovoked') | (Data['Type'] == 'Boat') | (Data['Type'] == 'Boating')]

Data = filtered_rows_types
print(Data.shape)
# Out:
# (4935, 24)

# %%
# CLEAN ROW WITH MORE THAN 8 NULL IN IT

null_counts = Data.isnull().sum(axis=1)

mask = null_counts > 8

filtered_data = Data[mask]

count_more_than_8_nulls = len(filtered_data)

print(count_more_than_8_nulls)
# Out:
# 14

# %%
# CLEAN ROW WITH MORE THAN 8 NULL IN IT

null_counts = Data.isnull().sum(axis=1)

mask1 = null_counts <= 8

filtered_data1 = Data[mask1]

print(filtered_data1.shape)
print(Data.shape)
# Out:
# (4921, 24)
# (4935, 24)

# %%
# CLEAN ROW WITH MORE THAN 8 NULL IN IT

Data = filtered_data1

# %%
# SAFETY COPY OF WORK DONE

Data1 = Data

# %%
column_titles = Data.columns
print("Column titles:", column_titles)
# Out:
# Column titles: Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
columns_to_check1 = ['Year', 'Country', 'Area']

# Iterate over the specified columns and print unique values
for column in columns_to_check1:
    unique_values1 = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values1))
# Out:
# Unique values of column 'Year': [2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007.
#  2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996. 1995.
#  1984. 1994. 1993. 1992. 1991. 1990. 1989. 1988. 1987. 1986. 1985. 1983.
#  1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973. 1972. 1971.
#  1970. 1969. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960. 1959.
#  1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948. 1848.
#  1947. 1946. 1945. 1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937. 1936.
#  1935. 1934. 1933. 1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925. 1924.
#  1923. 1922. 1921. 1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913. 1912.
#  1911. 1910. 1909. 1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901. 1900.
#  1899. 1898. 1897. 1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889. 1888.
#  1887. 1886. 1885. 1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877. 1876.
# ...

# %%
# CLEAN ROW WITH Year below 1950. AFTER 1950 STARTS SEVERE DAMAGE TO OCEANS AND COASTS, DISCHARGES AND INDUSTRIAL FISHING. 

countyear = len(Data[Data['Year'] < 1950])

# Calculate the total number of rows
total_rowsyear = len(Data)

# Calculate the percentage
percentageyear = (countyear / total_rowsyear) * 100

# Print the percentage
print(percentageyear)
# Out:
# 27.128632391790287

# %%
# CLEAN ROW WITH Year below 1950 and null

Data = Data[~((Data['Year'] < 1950) | Data['Year'].isnull())]

columns_to_checkx = ['Year']

# Iterate over the specified columns and print unique values
for column in columns_to_checkx:
    unique_valuesx = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_valuesx))
# Out:
# Unique values of column 'Year': [2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007.
#  2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996. 1995.
#  1984. 1994. 1993. 1992. 1991. 1990. 1989. 1988. 1987. 1986. 1985. 1983.
#  1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973. 1972. 1971.
#  1970. 1969. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960. 1959.
#  1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950.]

# %%
# CLEAN ROW WITH Year below 1950 and null
Data1 = Data
print(Data.shape)
# Out:
# (3585, 24)

# %%
# CLEAN COLUMN Country

country = Data['Country'].str.lower()

# Extract country names using regular expressions
country_names = country.str.extract(r'([a-z\s]+)')[0]

# Replace 'NaN' values with 'Unknown'
country_names = country_names.replace(np.nan, 'Unknown')

Data['Country'] = country_names
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\1289640257.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Country'] = country_names

# %%
# CLEAN COLUMN Country

columns_to_checky = ['Country']

# Iterate over the specified columns and print unique values
for column in columns_to_checky:
    unique_valuesy = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_valuesy))
    
print(Data.shape)
Data1 = Data
# Out:
# Unique values of column 'Country': ['usa' 'australia' 'brazil' 'south africa' 'thailand' 'costa rica'
#  'maldives' 'bahamas' 'new caledonia' 'ecuador' 'Unknown' 'cuba'
#  'mauritius' 'new zealand' 'spain' 'solomon islands' 'japan' 'egypt'
#  'st helena' 'reunion' 'french polynesia' 'united kingdom'
#  'united arab emirates' 'mexico' 'philippines' 'indonesia' 'china'
#  'columbia' 'fiji' 'dominican republic' 'aruba' 'mozambique' 'puerto rico'
#  'atlantic ocean' 'st' 'france' 'papua new guinea' 'kiribati' 'israel'
#  'diego garcia' 'taiwan' 'guam' 'seychelles' 'belize' 'jamaica' 'nigeria'
#  'tonga' 'scotland' 'kenya' 'russia' 'turks ' 'malaysia' 'samoa'
#  'south korea' 'malta' 'vietnam' 'madagascar' 'united arab emirates '
#  'panama' 'croatia' 'yemen' 'gulf of aden' 'sierra leone' 'grand cayman'
#  'vanuatu' 'mexico ' 'venezuela' ' tonga' 'uruguay' 'india' 'micronesia'
#  'italy' 'canada' 'okinawa' 'tanzania' 'marshall islands' 'egypt '
# ...

# %%
import re

# %%
# # CLEAN COLUMN Area

area_new = Data['Area'].copy()

# Apply the modification to keep only words starting with uppercase letters and remove numbers and characters
area_new = area_new.str.findall(r'\b[A-Z][a-zA-Z]*\b').str.join(' ')
Data['Area'] = area_new
Data.shape
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\1073745236.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Area'] = area_new
# (3585, 24)

# %%
Data1 = Data

# %%
columns_to_check2 = ['Sex ', 'Age', 'Fatal (Y/N)']

# Iterate over the specified columns and print unique values
for column in columns_to_check2:
    unique_values2 = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values2))
# Out:
# Unique values of column 'Sex ': ['F' 'M' nan 'M ' 'lli']
# Unique values of column 'Age': ['57' '11' nan '18' '52' '15' '12' '10' '30' '60' '32' '33' '29' '54' '34'
#  '41' '37' '19' '25' '69' '38' '55' '35' '45' '40s' '28' '20' '26' '49'
#  '14' '24' '22' '7' '31' '17' '40' '13' '42' '3' '50' '46' '16' '82' '48'
#  '20s' '21' '51' '39' '58' 'Teen' '47' '61' '65' '36' '66' '43' '60s' '9'
#  '72' '59' '6' '64' '23' '71' '44' '27' '62' '68' '63' '70' '18 months'
#  '53' '30s' '50s' '8' 'teen' '74' '56' '28 & 26' '5' '86' '18 or 20'
#  '12 or 13' '46 & 34' '28, 23 & 30' '77' '36 & 26' '84' '30 or 36' '6½'
#  '21 & ?' '33 or 37' 'mid-30s' '73' ' 30' ' 28' '20?' "60's" '32 & 30'
#  '87' 'Elderly' '75' ' ' '21 or 26' '20 ' '>50' '18 to 22' '9 & 12'
#  '9 months' '25 to 35' '23 & 26' '1' '(adult)' '25 or 28' '30 & 32'
#  '50 & 30' 'X' '"middle-age"' '13 or 18' '33 & 26' 'MAKE LINE GREEN' '81'
#  '"young"' '7 or 8']
# Unique values of column 'Fatal (Y/N)': ['N' 'Y' nan 'UNKNOWN' ' N']

# %%
# CLEAN COLUMN sex : F = 2, M = 1

mapping = {'F': 2, 'M': 1, 'M ': 1}


clean_sex = Data['Sex '].map(mapping).fillna('undefined')

Data['Sex '] = clean_sex
Data.shape
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\956773197.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Sex '] = clean_sex
# (3585, 24)

# %%
# CLEAN COLUMN Fatal : Yes = 2, No = 1, Undefined

mapping1 = {'Y': 2, 'N': 1, ' N': 1}

# Apply the mapping and replace other values with 'undefined'
clean1_fatal = Data['Fatal (Y/N)'].map(mapping1).fillna('undefined')

unique_values = pd.unique(clean1_fatal)

print(unique_values)
# Out:
# [1.0 2.0 'undefined']

# %%
# CLEAN COLUMN Fatal : 

Data['Fatal (Y/N)'] = clean1_fatal
Data.shape
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\2503596852.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Fatal (Y/N)'] = clean1_fatal
# (3585, 24)

# %%
Data1 = Data

# %%
# CLEAN COLUMN Age : 

unique_count = Data['Age'].nunique()
null_count = Data['Age'].isnull().sum()

print(unique_count)
print(null_count)
# Out:
# 123
# 1045

# %%
# CLEAN COLUMN Age :

count_letters = Data['Age'].str.isalpha().sum()

# Print the count of values with all letters
print(count_letters)
# Out:
# 13

# %%
# CLEAN COLUMN Age :

clean_age_1 = Data['Age'].replace({r'^[a-zA-Z]+$': np.nan}, regex=True)
unique_values_age = clean_age_1.unique()
print(unique_values_age)
# Out:
# ['57' '11' nan '18' '52' '15' '12' '10' '30' '60' '32' '33' '29' '54' '34'
#  '41' '37' '19' '25' '69' '38' '55' '35' '45' '40s' '28' '20' '26' '49'
#  '14' '24' '22' '7' '31' '17' '40' '13' '42' '3' '50' '46' '16' '82' '48'
#  '20s' '21' '51' '39' '58' '47' '61' '65' '36' '66' '43' '60s' '9' '72'
#  '59' '6' '64' '23' '71' '44' '27' '62' '68' '63' '70' '18 months' '53'
#  '30s' '50s' '8' '74' '56' '28 & 26' '5' '86' '18 or 20' '12 or 13'
#  '46 & 34' '28, 23 & 30' '77' '36 & 26' '84' '30 or 36' '6½' '21 & ?'
#  '33 or 37' 'mid-30s' '73' ' 30' ' 28' '20?' "60's" '32 & 30' '87' '75'
#  ' ' '21 or 26' '20 ' '>50' '18 to 22' '9 & 12' '9 months' '25 to 35'
#  '23 & 26' '1' '(adult)' '25 or 28' '30 & 32' '50 & 30' '"middle-age"'
#  '13 or 18' '33 & 26' 'MAKE LINE GREEN' '81' '"young"' '7 or 8']

# %%
# CLEAN COLUMN Age :

value_counts = clean_age_1.value_counts().reset_index()

# Rename the columns
value_counts.columns = ['Value', 'Count']

# Print the unique values and their counts
print(value_counts)
# Out:
#                Value  Count
# 0                 16    110
# 1                 19    106
# 2                 15    105
# 3                 17    104
# 4                 18    100
# 5                 20     92
# 6                 22     91
# 7                 21     87
# 8                 25     82
# 9                 24     80
# 10                14     75
# 11                13     68
# 12                26     66
# 13                28     64
# 14                29     61
# 15                23     57
# 16                27     56
# 17                35     56
# 18                30     54
# 19                12     52
# 20                32     51
# 21                40     43
# 22                10     42
# 23                31     40
# 24                37     36
# 25                42     32
# 26                34     32
# 27                38     32
# 28                33     31
# 29                41     31
# 30                36     28
# 31                39     26
# ...

# %%
# CLEAN COLUMN Age :

value_counts = clean_age_1.dropna().value_counts()

# Transform the values that occur only once into null
clean_age_2 = clean_age_1.apply(lambda x: None if x in value_counts and value_counts[x] == 1 else x)

clean_age_2 = clean_age_2.str.replace('s', '')

median_age = clean_age_2.dropna().median()

clean_age_2 = clean_age_2.fillna(median_age)

unique_values_age2 = clean_age_2.unique()
print(unique_values_age2)
# Out:
# ['57' '11' 24.0 '18' '52' '15' '12' '10' '30' '60' '32' '33' '29' '54'
#  '34' '41' '37' '19' '25' '69' '38' '55' '35' '45' '40' '28' '20' '26'
#  '49' '14' '24' '22' '7' '31' '17' '13' '42' '50' '46' '16' '48' '21' '51'
#  '39' '58' '47' '61' '65' '36' '66' '43' '9' '59' '6' '64' '23' '71' '44'
#  '27' '62' '68' '63' '70' '53' '8' '56' '5']

# %%
# CLEAN COLUMN Age :

clean_age_4 = clean_age_2
clean_age_4 = clean_age_4.replace(24.0, 24)

unique_values_age4 = clean_age_4.unique()
print(unique_values_age4)
# Out:
# ['57' '11' 24 '18' '52' '15' '12' '10' '30' '60' '32' '33' '29' '54' '34'
#  '41' '37' '19' '25' '69' '38' '55' '35' '45' '40' '28' '20' '26' '49'
#  '14' '24' '22' '7' '31' '17' '13' '42' '50' '46' '16' '48' '21' '51' '39'
#  '58' '47' '61' '65' '36' '66' '43' '9' '59' '6' '64' '23' '71' '44' '27'
#  '62' '68' '63' '70' '53' '8' '56' '5']

# %%
# CLEAN COLUMN Age :

shape = clean_age_4.shape

# Print the shape
print(shape)
# Out:
# (3585,)

# %%
Data['Age'] = clean_age_4
Data.shape
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\4036191364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Age'] = clean_age_4
# (3585, 24)

# %%
Data1 = Data

# %%
columns_to_check5 = ['Species ', 'Activity']

# Iterate over the specified columns and print unique values
for column in columns_to_check5:
    unique_values5 = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values5))
# Out:
# Unique values of column 'Species ': ['White shark' nan '2 m shark' ... 'Whtietip reef shark'
#  "Tiger shark, 3.7 m to 4.3 m  [12' to 14']"
#  "2.7 m [9'] shark with black-tipped pectoral fins"]
# Unique values of column 'Activity': ['Paddling' 'Standing' 'Surfing' 'Kite surfing' 'Swimming' 'Fishing'
#  'Walking' 'Boogie boarding' 'Scuba diving' 'Paddle-skiing'
#  'Body boarding' 'Windsurfing' 'Stand-Up Paddleboarding' 'Wading'
#  'Scuba Diving' 'Snorkeling' nan 'Spearfishing' 'Diving' 'Free diving'
#  'Night bathing' 'Surfing ' 'Kayaking / Fishing' 'Kayaking' 'Body surfing'
#  'Swimming, poaching abalone' 'Canoeing' 'SUP' 'Skimboarding'
#  'Feeding sharks' 'Paddle boarding' 'Kakaying' 'Washing hands'
#  'Kayak fishing' 'Tagging sharks' 'Surf skiing ' 'Floating' 'Surfng'
#  'SUP Foil boarding' 'Fishing in Alabama Deep Fishing Rodeo'
#  'Fishing for squid' 'Fishing for sharks' 'Floating in tube' 'Surf-skiing'
#  'Diving for beche-de-mer' 'Kayak Fishing' 'Sea disaster'
# ...

# %%
columns_to_check6 = ['Species ']

# Iterate over the specified columns and print unique values
for column in columns_to_check6:
    unique_values6 = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values6))
# Out:
# Unique values of column 'Species ': ['White shark' nan '2 m shark' ... 'Whtietip reef shark'
#  "Tiger shark, 3.7 m to 4.3 m  [12' to 14']"
#  "2.7 m [9'] shark with black-tipped pectoral fins"]

# %%
Data.shape
# Out:
# (3585, 24)

# %%
Data['Species '] = Data['Species '].str.replace(r'[^a-zA-Z0-9\s]', '')
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\3980582512.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Data['Species '] = Data['Species '].str.replace(r'[^a-zA-Z0-9\s]', '')
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\3980582512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Species '] = Data['Species '].str.replace(r'[^a-zA-Z0-9\s]', '')

# %%
measurements = Data['Species '].str.extract(r'(\d+\.?\d* ?[mM\']{1,2}|\d+ ?- ?\d+ kg|\d+ ?- ?\d+ lb)')[0]

measurements.shape

unique_values = set(measurements)
print("Unique values in the variable:")
print(unique_values)

non_null_count = sum(pd.notnull(measurements))
print("Number of non-null values in the variable:", non_null_count)
# Out:
# Unique values in the variable:
# {'31 m', '24 m', '21 m', '2m', '7m', '5m', '09 m', '15 m', '49 m', '7 m', '35 m', '37 m', '4m', '28 m', '46 m', '29 m', '67 m', '165 m', '26 m', '23m', '6m', '28m', '43 m', '13 m', '12 m', '18 mm', '6 m', '213 m', '19 m', '18 m', '57 m', '15m', '17 m', '37m', '65 m', '45 m', '12m', '1m', '58 m', '25 m', '16 m', '36 m', '3 m', '35m', '16m', '5 m', '25m', '227 m', '3m', '06 m', '1 m', '2 m', '07 m', '42 m', '52 m', '27m', '32 m', '14m', '48 m', '55 m', '45m', '22 m', '44 m', '14 m', nan, '18m', '4 m', '23 m', '27 m', '34 m'}
# Number of non-null values in the variable: 1031

# %%
columns_to_check7 = ['Species ']

# Iterate over the specified columns and print unique values
for column in columns_to_check7:
    unique_values7 = Data[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values7))

Data12 = Data
# Out:
# Unique values of column 'Species ': ['White shark' nan '2 m shark' ... 'Whtietip reef shark'
#  'Tiger shark 37 m to 43 m  12 to 14'
#  '27 m 9 shark with blacktipped pectoral fins']

# %%
import pandas as pd
import re

# Clean the values in the column
cleaned_skr = Data['Species '].map(lambda x: re.sub(r'[^a-zA-Z\s]+', '', str(x)).strip())

# Get the unique cleaned values
unique_skr = cleaned_skr.unique()

# %%
cleaned_skr = Data['Species '].astype(str).apply(lambda x: re.sub(r'\b\w{1,2}\b|shark', '', x))

# Get the unique cleaned values
unique_skr1 = cleaned_skr.unique()

value_counts = cleaned_skr.value_counts()

# Print the value counts
print(value_counts)
# Out:
# nan                                                                                                                                                                  1409
#                                                                                                                                                                       237
#                                                                                                                                                                       149
# White                                                                                                                                                                 146
#                                                                                                                                                                        89
# ...

# %%
# Capitalize the first letter of each word in the list
capitalized_cleaned_skr = [s.title() for s in cleaned_skr]

# Get the unique values in the list
unique_species = list(set(capitalized_cleaned_skr))

# Print the unique species
print(unique_species)
# Out:
# [' ', ' 8132005 Anglers From New Zealand Caught     140Kg 309Lb   The Same Spot  Was Believed This Was The Same  That Killed Alysha', '     825    White ', ' Bull  12M ', 'White  25M', '   Dusky ', 'Reported  Involve  White ', 'Caribbean Reef S', 'Raggedtooth    675 ', '270  ', 'Mako    675 ', 'Two    S', ' S Involved', 'Said  Involve    ', 'White       165   ', 'Possibly  Bronze Whaler ', 'Juvenile Dusky ', 'Possibly  Sandbar   Small Blacktip ', 'Gray ', '         Tooth Fragment Recovered From Hand', 'White    ', 'Oceanic Whitetip  25M ', ' Tiger  28M', 'Mako     ', 'Bronze Whaler', '  825 Bull ', '         ', '   18M    ', 'Thought  Involve     400Lb Bull ', 'Blacktip Reef  Pup', 'Bronze Whaler  25M', '        Grey Colored ', 'Small ', 'Tiger  23M ', 'Grey Reef    ', 'Porbeagle    10Rk', 'Possibly  Sand ', '  ', '   Blacktip   Caribbean Reef ', 'White  Based   Teeth Retrieved From Rudder', 'Hammerhead ', 'Bronze Whaler    825 ', 'White    119 ', 'Tiger           ', 'Bull  25M', 'Bu
# ...

# %%
capitalized_cleaned_skr = [np.nan if x == '' else x for x in capitalized_cleaned_skr]
capitalized_cleaned_skr = [x.replace(' ', '') for x in capitalized_cleaned_skr]
unique_species = list(set(capitalized_cleaned_skr))

# %%
capitalized_cleaned_skr = [re.findall(r'(?:\b(Tiger|White|Bull|Wobbegong|BlackTip|Blacktip|BronzeWhaler|Blue|Raggedtooth|RaggeedTooth|Hammerhead|WhiteTip|Whitetip|Spinner|Mako|Carpet|Lemon|GreyReef|Greyreef|GrayReef|Grayreef|Nurse)\b)', x.strip())[0] if re.findall(r'(?:\b(Tiger|White|Bull|Wobbegong|BlackTip|Blacktip|BronzeWhaler|Blue|Raggedtooth|RaggeedTooth|Hammerhead|WhiteTip|Whitetip|Spinner|Mako|Carpet|Lemon|GreyReef|Greyreef|GrayReef|Grayreef|Nurse)\b)', x.strip()) else np.nan for x in capitalized_cleaned_skr]

# %%
unique_species = list(set(capitalized_cleaned_skr))

# Print the unique species
print(unique_species)
# Out:
# ['GreyReef', 'White', 'Nurse', 'Bull', 'Blue', 'Raggedtooth', 'Spinner', 'Mako', 'Wobbegong', 'Lemon', nan, 'Tiger', 'BronzeWhaler', 'Hammerhead', 'GrayReef', 'Carpet', 'Blacktip']

# %%
capitalized_cleaned_skr = [x if isinstance(x, str) else "Undefined" for x in capitalized_cleaned_skr]

# %%
unique_species = list(set(capitalized_cleaned_skr))

# Print the unique species
print(unique_species)
# Out:
# ['GreyReef', 'White', 'Nurse', 'Bull', 'Blue', 'Hammerhead', 'Raggedtooth', 'Spinner', 'Mako', 'Wobbegong', 'Lemon', 'BronzeWhaler', 'Tiger', 'Undefined', 'GrayReef', 'Carpet', 'Blacktip']

# %%
Data['Species '] = clean_age_4
Data.shape
# Out:
# C:\Users\demia\AppData\Local\Temp\ipykernel_11704\2363822800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Species '] = clean_age_4
# (3585, 24)
