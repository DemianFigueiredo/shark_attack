# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Shark_Path = 'attacks.csv'

Shark = pd.read_csv(Shark_Path, encoding='latin-1')

pd.set_option('display.max_columns', None)

# %%
Shark.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
print(Shark.shape)
# Out:
# (25723, 24)

# %%
Shark.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
null_counts = Shark.isnull().sum()
print(null_counts[null_counts > 0])
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
all_null_rows_count = Shark.isnull().all(axis=1).sum()
all_null_rows_count
# Out:
# 17020

# %%
Shark_cleaned = Shark.dropna(how='all')
Shark_cleaned.head( )
print(Shark_cleaned.shape)
# Out:
# (8703, 24)

# %%
print(Shark.shape)
# Out:
# (25723, 24)

# %%
print(Shark.shape)
# Out:
# (25723, 24)

# %%
unique_values = Shark['Type'].unique()
unique_values
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
count_2 = Shark['Type'].value_counts()['Provoked']
count_2
# Out:
# 574

# %%
count_2 = Shark['Type'].value_counts()['Invalid']
count_2
# Out:
# 547

# %%
count_2 = Shark['Type'].value_counts()['Boatomg']
count_2
# Out:
# 1

# %%
count_2 = Shark['Type'].value_counts()['Sea Disaster']
count_2
# Out:
# 239

# %%
count_2 = Shark['Type'].value_counts()['Unprovoked']
count_2
# Out:
# 4595

# %%
count_2 = Shark['Type'].value_counts()['Boating']
count_2
# Out:
# 203

# %%
count_2 = Shark['Type'].value_counts()['Questionable']
count_2
# Out:
# 2

# %%
count_2 = Shark['Type'].value_counts()['Boat']
count_2
# Out:
# 137

# %%
filtered_rows_ = Shark[Shark['Type'] == 'Boating']
filtered_rows_
# Out:
#        Case Number                  Date    Year     Type       Country  \
# 0       2018.06.25           25-Jun-2018  2018.0  Boating           USA
# 86      2017.09.14              Sep-2017  2017.0  Boating     AUSTRALIA
# 105     2017.08.01           01-Aug-2017  2017.0  Boating           USA
# 116   2017.07.20.b           20-Jul-2017  2017.0  Boating           USA
# 120     2017.07.11           11-Jul-2017  2017.0  Boating           USA
# ...            ...                   ...     ...      ...           ...
# 5880    1874.07.23           23-Jul-1874  1874.0  Boating        FRANCE
# 5887  1874.04.20.R  Reported 20-Apr-1874  1874.0  Boating        CANADA
# 5930  1867.01.26.R  Reported 26-Jan-1867  1867.0  Boating     AUSTRALIA
# 5936  1865.03.01.R  Reported 01-Mar-1865  1865.0  Boating  SOUTH AFRICA
# 5937    1865.00.00                  1865  1865.0  Boating     AUSTRALIA
#
#                        Area  \
# 0                California
# 86        Westerm Australia
# ...

# %%
filtered_rows_ = Shark[Shark['Type'] == 'Boat']
filtered_rows_
# Out:
#        Case Number                     Date    Year  Type       Country  \
# 538   2014.06.27.R     Reported 27-Jun-2014  2014.0  Boat    ST. MARTIN
# 565   2014.04.12.R     Reported 12-Apr-2014  2014.0  Boat  SOUTH AFRICA
# 706     2013.01.26              26-Jan-2013  2013.0  Boat     AUSTRALIA
# 818     2012.02.20              20-Feb-2012  2012.0  Boat  SOUTH AFRICA
# 864     2011.09.20              20-Sep-2011  2011.0  Boat           USA
# ...            ...                      ...     ...   ...           ...
# 6127  1804.02.26.R     Reported 26-Feb-1804  1804.0  Boat     AUSTRALIA
# 6136    1788.05.10              10-May-1788  1788.0  Boat     AUSTRALIA
# 6145  1776.00.00.b                     1776  1776.0  Boat     GREENLAND
# 6212       ND-0107              Before 2004     0.0  Boat    MOZAMBIQUE
# 6274       ND.0028  A few years before 1938     0.0  Boat         ITALY
#
#                        Area                        Location  \
# ...

# %%
filtered_rows_types = Shark[(Shark['Type'] == 'Unprovoked') | (Shark['Type'] == 'Boat') | (Shark['Type'] == 'Boating')]

# %%
filtered_rows_types
# Out:
#        Case Number         Date    Year        Type             Country  \
# 0       2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1       2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 3       2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 5     2018.06.03.b  03-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 6     2018.06.03.a  03-Jun-2018  2018.0  Unprovoked              BRAZIL
# ...            ...          ...     ...         ...                 ...
# 6297       ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298       ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299       ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300       ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301       ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
Shark = filtered_rows_types
print(Shark.shape)
# Out:
# (4935, 24)

# %%
Shark.head()
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
#
#                          Location      Activity                    Name Sex   \
# 0     Oceanside, San Diego County      Paddling             Julie Wolfe    F
# 1  St. Simon Island, Glynn County      Standing         Adyson McNeely     F
# 3              Arrawarra Headland       Surfing                    male    M
# 5              Flat Rock, Ballina  Kite surfing                 Chris
#     M
# 6           Piedade Beach, Recife      Swimming  Jose Ernesto da Silva     M
#
# ...

# %%
null_counts = Shark[['Case Number', 'Date', 'Year', "Case Number.1" , "Case Number.2", "original order"]].isnull().sum()
print(null_counts)
# Out:
# Case Number       0
# Date              0
# Year              1
# Case Number.1     0
# Case Number.2     0
# original order    0
# dtype: int64

# %%
null_rows = Shark[Shark['Year'].isnull()]
null_rows

null_indices = null_rows.index
null_rows
null_indices
# Out:
# Int64Index([6079], dtype='int64')

# %%
Shark = Shark.drop(null_indices)
Shark.head()
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
#
#                          Location      Activity                    Name Sex   \
# 0     Oceanside, San Diego County      Paddling             Julie Wolfe    F
# 1  St. Simon Island, Glynn County      Standing         Adyson McNeely     F
# 3              Arrawarra Headland       Surfing                    male    M
# 5              Flat Rock, Ballina  Kite surfing                 Chris
#     M
# 6           Piedade Beach, Recife      Swimming  Jose Ernesto da Silva     M
#
# ...

# %%
null_counts = Shark.isnull().sum(axis=1)

# Filter rows with more than 8 null values
rows_with_more_than_8_nulls = Shark[null_counts > 8
                                     ]

# Print the rows with more than 8 null values
print(rows_with_more_than_8_nulls)
# Out:
#        Case Number                    Date    Year        Type  \
# 2196    1998.04.00                Apr-1998  1998.0  Unprovoked
# 3378    1970.11.00                Nov-1970  1970.0  Unprovoked
# 3938  1961.00.00.d                    1961  1961.0  Unprovoked
# 5029  1931.00.00.a                    1931  1931.0  Unprovoked
# 5036  1930.09.12.R                    1930  1930.0     Boating
# 5812  1881.00.00.b                    1881  1881.0  Unprovoked
# 5846  1878.03.30.R  Reported 30-March-1878  1878.0  Unprovoked
# 5880    1874.07.23             23-Jul-1874  1874.0     Boating
# 6081  1836.00.00.a                1836.00.  1836.0  Unprovoked
# 6130  1802.04.13.R    Reported Apr-13-1802  1802.0  Unprovoked
# 6133  1797.05.28.R    Reported May-28-1797  1797.0  Unprovoked
# 6158    1723.00.00                    1723  1723.0  Unprovoked
# 6165  1638.00.00.R           Reported 1638  1638.0  Unprovoked
# 6171    1555.00.00                    1555  1555.0  Unprovoked
#
# ...

# %%
num_rows = len(rows_with_more_than_8_nulls)
print(num_rows)
# Out:
# 14

# %%
print(Shark.shape)
Shark.drop(rows_with_more_than_8_nulls.index, inplace=True)
print(Shark.shape)
# Out:
# (4934, 24)
# (4920, 24)

# %%
column_to_check = 'column_name'

# Find duplicate values in the specified column
duplicate_values = df[df.duplicated(subset=column_to_check)]

# Print the duplicate values
print("Duplicate values in the column:", duplicate_values)

# %%
columns_to_check1 = ['Year', 'Country', 'Area']

# Iterate over the specified columns and print unique values
for column in columns_to_check1:
    unique_values1 = Shark[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values1))
# Out:
# Unique values of column 'Year': [2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007.
#  2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996. 1995.
#  1984. 1994. 1993. 1992. 1991. 1990. 1989. 1988. 1987. 1986. 1985. 1983.
#  1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973. 1972. 1971.
#  1970. 1969. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960. 1959.
#  1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948. 1848.
#  1947. 1946. 1945. 1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937. 1936.
#  1935. 1934. 1933. 1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925. 1924.
#  1923. 1922. 1921. 1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913. 1912.
#  1911. 1910. 1909. 1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901. 1900.
#  1899. 1898. 1897. 1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889. 1888.
#  1887. 1886. 1885. 1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877. 1876.
# ...

# %%
column_titles = Shark.columns
print("Column titles:", column_titles)
# Out:
# Column titles: Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
''''
Para Year 
A partir das décadas de 1950 e 1960, observou-se um aumento significativo na poluição 
dos oceanos devido ao descarte inadequado de resíduos industriais, derramamentos de 
petróleo e produtos químicos, além da deposição de poluentes atmosféricos. 
Esse período também marcou o início da pesca excessiva e da destruição de habitats costeiras.

Para País 
colocar tudo maiscula
quantas vezes cada país repete
apagar países que repetem menos x vezes que y (nao sei se uso número/media?)

Para Área
Primeira letra Maiscula de cada palavra o restante da palavra minuscula
Editar palavras com (
d\x92Étang-Salé
transformar em Unknown values que contem º, miles, KM, números

'''

# %%
columns_to_check2 = ['Sex ', 'Age', 'Fatal (Y/N)']

# Iterate over the specified columns and print unique values
for column in columns_to_check2:
    unique_values2 = Shark[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values2))
# Out:
# Unique values of column 'Sex ': ['F' 'M' nan 'M ' 'lli' 'N']
# Unique values of column 'Age': ['57' '11' nan '18' '52' '15' '12' '10' '30' '60' '32' '33' '29' '54' '34'
#  '41' '37' '19' '25' '69' '38' '55' '35' '45' '40s' '28' '20' '26' '49'
#  '14' '24' '22' '7' '31' '17' '40' '13' '42' '3' '50' '46' '16' '82' '48'
#  '20s' '21' '51' '39' '58' 'Teen' '47' '61' '65' '36' '66' '43' '60s' '9'
#  '72' '59' '6' '64' '23' '71' '44' '27' '62' '68' '63' '70' '18 months'
#  '53' '30s' '50s' '8' 'teen' '74' '56' '28 & 26' '5' '86' '18 or 20'
#  '12 or 13' '46 & 34' '28, 23 & 30' '77' '36 & 26' '84' '30 or 36' '6½'
#  '21 & ?' '33 or 37' 'mid-30s' '73' ' 30' ' 28' '20?' "60's" '32 & 30'
#  '87' 'Elderly' '75' ' ' '21 or 26' '20 ' '>50' '18 to 22' '9 & 12'
#  '9 months' '25 to 35' '23 & 26' '1' '(adult)' '25 or 28' '30 & 32'
#  '50 & 30' 'X' '"middle-age"' '13 or 18' '33 & 26' 'MAKE LINE GREEN' '81'
#  '"young"' '7 or 8' '78' '17 & 16' '8 or 10' 'Both 11' '9 or 10' '  '
# ...

# %%
''''
Para Sex
Arrumar título da coluna, tira espaço do SEX
tirar espaço de 'M ', tem que ficar como "M"
Transformar M = 1, F = 2, (nan, lli, N) = 0 = undefined
Fazer legenda

Para Age 
transformar em decadas: ex: from 40 to 49 to 40's
algo mais?
undefined = Elderly, MAKE LINE GREEN
1 numero com or, e depois 1 numero, manter primeiro 

Para Fatal
tirar espaço de ' N ', tem que ficar como "N"
colocar letra Maiscula
Transformar N = 1, Y = 2, (nan,UNKNOWN) = 0 = undefined

'''

# %%
columns_to_check3 = ['Activity', 'Species ', 'Time']

# Iterate over the specified columns and print unique values
for column in columns_to_check3:
    unique_values3 = Shark[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values3))
# Out:
# Unique values of column 'Activity': ['Paddling' 'Standing' 'Surfing' ...
#  'Crew swimming alongside their anchored ship' '4 men were bathing'
#  'Wreck of  large double sailing canoe']
# Unique values of column 'Species ': ['White shark' nan '2 m shark' ... "12' tiger shark" 'Blue pointers'
#  'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable']
# Unique values of column 'Time': ['18h00' '14h00  -15h00' nan 'Late afternoon' '17h00' '14h00' '15h00'
#  '11h00' '10h40' '16h50' '09h30' 'Afternoon' '21h50' '09h40' '08h00'
#  '17h35' '15h30' '07h30' '19h00, Dusk' '16h00' '15h01' '12h00' '13h45'
#  '23h30' '09h00' '14h30' '18h30' '12h30' 'Morning' '16h30' '18h45' '06h00'
#  '10h00' '10h44' '10h30' '13h19' '13h30' '10h45' '11h20' '07h45' '11h45'
#  '08h30' '15h45' 'Shortly before 12h00' '17h34' '17h10' '11h15' '17h45'
#  '13h00' '10h20' '13h20' '07h00' '09h50' '11h30' '17h30' '9h00' '10h43'
# ...

# %%
columns_to_check3 = ['Species ']

# Iterate over the specified columns and print unique values
for column in columns_to_check3:
    unique_values3 = Shark[column].unique()
    print("Unique values of column '{}': {}".format(column, unique_values3))
# Out:
# Unique values of column 'Species ': ['White shark' nan '2 m shark' ... "12' tiger shark" 'Blue pointers'
#  'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable']

# %%
''''
Para TIME


Para Species


Para Fatal
tirar espaço de ' N ', tem que ficar como "N"
colocar letra Maiscula
Transformar N = 1, Y = 2, (nan,UNKNOWN) = 0 = undefined
